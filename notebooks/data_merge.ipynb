# %%
import os
from os.path import join

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)

# %%
# Path to the directory containing files
directory_path = '../data'

# List all files in the directory and filter to include only those that start with 'airbnb_'
airbnb_files = [file for file in os.listdir(directory_path) if file.startswith('airbnb_')]

data = pd.read_csv(join(directory_path, airbnb_files[0]))

# Read the data
for data_filename in airbnb_files[1:]:
    new_data = pd.read_csv(join(directory_path, data_filename))
    data = pd.concat([data, new_data])

# %%
#data.to_csv("../data/raw_data.csv", index=False)

# %% [markdown]
# ### Some EDA and statistics

# %%
missing_count = new_data.isna().sum().sum()
print(f'Number of missing values: {missing_count}')
print(f'Rows in dataset: {data.shape[0]}, columns in dataset: {data.shape[1]}\n')

print("Example data:")
data.head()
# Out:
# Number of missing values: 0
# Rows in dataset: 2399, columns in dataset: 25
#
# Example data:
#                     id     userId                                        name  \
# 0             36322781   22847334   Cozy Comfy Guest Suite (Nanaimo Skytrain)
# 1             51320938   30084673           NEW, clean, modern, private suite
# 2  1152216438211720822   57959028                 Pet friendly Gem in Gastown
# 3             34203078  258206915  Downtown Vancouver Coal Harbour w/ parking
# 4             21356520   11824155   Private and spacious  room in upper floor
#
#                  address       city  isSuperhost       lat        lng  \
# 0  Vancouver, BC, Canada  Vancouver         True  49.25094 -123.05199
# 1  Vancouver, BC, Canada  Vancouver         True  49.25369 -123.09964
# 2  Vancouver, BC, Canada  Vancouver         True  49.28272 -123.10362
# 3  Vancouver, BC, Canada  Vancouver        False  49.28618 -123.12312
# 4  Vancouver, BC, Canada  Vancouver         True  49.23965 -123.04831
#
#    persons  rating  reviewsCount                  type  \
# 0        2    4.91           283    Entire guest suite
# 1        2    4.92           107           Entire home
# 2        3    0.00             0    Entire rental unit
# 3        4    4.76           369          Entire condo
# 4        2    4.90           112  Private room in home
#
#                              cancelPolicy  \
# 0                         CANCEL_MODERATE
# 1  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
# 2                         CANCEL_FLEXIBLE
# 3                         CANCEL_MODERATE
# 4                         CANCEL_MODERATE
#
#                                             deeplink  \
# 0  https://www.airbnb.com/rooms/36322781?check_in...
# 1  https://www.airbnb.com/rooms/51320938?check_in...
# 2  https://www.airbnb.com/rooms/11522164382117208...
# 3  https://www.airbnb.com/rooms/34203078?check_in...
# 4  https://www.airbnb.com/rooms/21356520?check_in...
#
#                                        hostThumbnail price_currency  \
# 0  https://a0.muscache.com/im/pictures/user/75bc6...            CAD
# 1  https://a0.muscache.com/im/pictures/user/27680...            CAD
# 2  https://a0.muscache.com/im/pictures/user/User-...            CAD
# 3  https://a0.muscache.com/im/pictures/user/3325b...            CAD
# 4  https://a0.muscache.com/im/pictures/user/eeb58...            CAD
#
#    price_rate  price_total  bathrooms  bedrooms  beds  \
# 0         174          696        1.0         1     1
# 1         224          896        1.0         1     2
# 2         312         1248        1.0         1     1
# 3         469         1873        1.0         1     3
# 4         107          427        1.0         1     1
#
#                              previewAmenities  \
# 0  Free parking, Wifi, Kitchen, Self check-in
# 1                Wifi, Kitchen, Self check-in
# 2                               Wifi, Kitchen
# 3  Free parking, Wifi, Kitchen, Self check-in
# 4                          Free parking, Wifi
#
#                                                 url  \
# 0             https://www.airbnb.com/rooms/36322781
# 1             https://www.airbnb.com/rooms/51320938
# 2  https://www.airbnb.com/rooms/1152216438211720822
# 3             https://www.airbnb.com/rooms/34203078
# 4             https://www.airbnb.com/rooms/21356520
#
#                                               images  \
# 0  ['https://a0.muscache.com/im/pictures/521551d8...
# 1  ['https://a0.muscache.com/im/pictures/400ac6fc...
# 2  ['https://a0.muscache.com/im/pictures/miso/Hos...
# 3  ['https://a0.muscache.com/im/pictures/eaee26aa...
# 4  ['https://a0.muscache.com/im/pictures/edcf7494...
#
#                                           amenityIds
# 0  [1, 4, 8, 9, 522, 77, 79, 657, 85, 86, 23, 89,...
# 1  [1, 33, 34, 35, 4, 100, 8, 40, 41, 44, 45, 51,...
# 2         [1, 33, 35, 99, 179, 4, 36, 37, 8, 12, 47]
# 3  [1, 4, 5, 8, 9, 137, 10, 522, 657, 21, 663, 66...
# 4  [1, 129, 2, 4, 9, 73, 522, 77, 79, 146, 85, 86...

# %%
# type                                number of values
data.type.value_counts()
# Out:
# Private room in home                  727
# Entire guest suite                    510
# Entire home                           312
# Entire rental unit                    298
# Entire condo                          189
# Entire guesthouse                      75
# Private room in villa                  38
# Private room in condo                  36
# Private room in rental unit            33
# Entire loft                            32
# Private room in bed and breakfast      26
# Private room in guest suite            23
# Private room in townhouse              21
# Room in hotel                           9
# Private room in guesthouse              8
# Tiny home                               8
# Entire townhouse                        8
# Room in boutique hotel                  6
# Private room in farm stay               5
# Entire serviced apartment               4
# Boat                                    4
# Private room in boat                    4
# Private room in tiny home               3
# Entire cottage                          2
# Camper/RV                               2
# Houseboat                               2
# Private room in bungalow                2
# Shared room in home                     2
# Entire villa                            2
# Entire vacation home                    1
# Private room                            1
# Private room in houseboat               1
# Private room in resort                  1
# Entire place                            1
# Shared room in condo                    1
# Private room in casa particular         1
# Private room in serviced apartment      1
# Name: type, dtype: int64

# %%
# type               number of values
data.city.value_counts()
# Out:
# Vancouver            1235
# Richmond              356
# North Vancouver       291
# Surrey                131
# Burnaby               107
# West Vancouver         85
# Delta                  74
# Coquitlam              20
# New Westminster        19
# Maple Ridge            17
# Port Moody             15
# Langley Township       10
# Metro Vancouver         9
# Langley                 7
# Port Coquitlam          5
# Tsawwassen              5
# Greater Vancouver       4
# Blaine                  3
# White Rock              3
# Belcarra                1
# Pitt Meadows            1
# Anmore                  1
# Name: city, dtype: int64

# %%
# type                 number of values
data.id.value_counts()
# Out:
# 624652822501750219     8
# 912668780036644741     8
# 794941413172112483     7
# 37002582               6
# 4022323                6
#                       ..
# 759718085882883202     1
# 851057341643129120     1
# 14868541               1
# 1157516693627912166    1
# 19744355               1
# Name: id, Length: 1438, dtype: int64

# 45   ['https://a0.muscache.com/im/pictures/miso/Hos...
# 203  ['https://a0.muscache.com/im/pictures/miso/Hos...
#
#                                             amenityIds
# 164  [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...
# 133  [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...
# 67   [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...
# 186  [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...
# 37   [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...
# 109  [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...
# 45   [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...
# 203  [1, 4, 5, 8, 9, 137, 394, 657, 23, 663, 280, 2...

# %%
df_unique = data.drop_duplicates(subset=['id', 'lat', 'lng', 'type'], keep='last')

print(df_unique.shape)

df_unique.head()
# Out:
# (1443, 25)
#                     id     userId  \
# 1             51320938   30084673
# 4             21356520   11824155
# 5  1064160331460880461   32377505
# 7  1061140108656427369  527093571
# 8   660744993743958889   79910358
#
#                                              name                address  \
# 1               NEW, clean, modern, private suite  Vancouver, BC, Canada
# 4       Private and spacious  room in upper floor  Vancouver, BC, Canada
# 5    Well-connected bright suite with home office  Vancouver, BC, Canada
# 7         Gorgeous 1Bd With Private Rooftop Patio  Vancouver, BC, Canada
# 8  Funky 1 bedroom in downtown Van (AC & Parking)  Vancouver, BC, Canada
#
#         city  isSuperhost        lat         lng  persons  rating  \
# 1  Vancouver         True  49.253690 -123.099640        2    4.92
# 4  Vancouver         True  49.239650 -123.048310        2    4.90
# 5  Vancouver         True  49.252542 -123.083299        2    4.81
# 7  Vancouver        False  49.284599 -123.129932        2    4.80
# 8  Vancouver         True  49.277760 -123.127970        3    4.86
#
#    reviewsCount                  type                            cancelPolicy  \
# 1           107           Entire home  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
# 4           112  Private room in home                         CANCEL_MODERATE
# 5            16    Entire guest suite      CANCEL_STRICT_14_WITH_GRACE_PERIOD
# 7             5    Entire rental unit                         CANCEL_MODERATE
# 8           100          Entire condo      CANCEL_STRICT_14_WITH_GRACE_PERIOD
#
#                                             deeplink  \
# 1  https://www.airbnb.com/rooms/51320938?check_in...
# 4  https://www.airbnb.com/rooms/21356520?check_in...
# 5  https://www.airbnb.com/rooms/10641603314608804...
# 7  https://www.airbnb.com/rooms/10611401086564273...
# 8  https://www.airbnb.com/rooms/66074499374395888...
#
#                                        hostThumbnail price_currency  \
# 1  https://a0.muscache.com/im/pictures/user/27680...            CAD
# 4  https://a0.muscache.com/im/pictures/user/eeb58...            CAD
# 5  https://a0.muscache.com/im/pictures/user/9a930...            CAD
# 7  https://a0.muscache.com/im/pictures/user/User-...            CAD
# 8  https://a0.muscache.com/im/pictures/user/User-...            CAD
#
#    price_rate  price_total  bathrooms  bedrooms  beds  \
# 1         224          896        1.0         1     2
# 4         107          427        1.0         1     1
# 5         207          827        1.0         1     1
# 7         429         1714        1.0         0     0
# 8         435         1738        1.0         1     2
#
#                              previewAmenities  \
# 1                Wifi, Kitchen, Self check-in
# 4                          Free parking, Wifi
# 5           Free parking, Wifi, Self check-in
# 7                Wifi, Kitchen, Self check-in
# 8  Free parking, Wifi, Kitchen, Self check-in
#
#                                                 url  \
# 1             https://www.airbnb.com/rooms/51320938
# 4             https://www.airbnb.com/rooms/21356520
# 5  https://www.airbnb.com/rooms/1064160331460880461
# 7  https://www.airbnb.com/rooms/1061140108656427369
# 8   https://www.airbnb.com/rooms/660744993743958889
#
#                                               images  \
# 1  ['https://a0.muscache.com/im/pictures/400ac6fc...
# 4  ['https://a0.muscache.com/im/pictures/edcf7494...
# 5  ['https://a0.muscache.com/im/pictures/hosting/...
# 7  ['https://a0.muscache.com/im/pictures/hosting/...
# 8  ['https://a0.muscache.com/im/pictures/miso/Hos...
#
#                                           amenityIds
# 1  [1, 33, 34, 35, 4, 100, 8, 40, 41, 44, 45, 51,...
# 4  [1, 129, 2, 4, 9, 73, 522, 77, 79, 146, 85, 86...
# 5  [4, 392, 9, 73, 137, 522, 77, 79, 657, 146, 85...
# 7  [1, 33, 34, 35, 4, 36, 37, 39, 8, 40, 41, 45, ...
# 8  [1, 4, 5, 8, 9, 137, 10, 522, 12, 15, 145, 657...

# %%
df_unique.id.value_counts()
# Out:
# 890071179418306206     2
# 978918152395569293     2
# 17302474               2
# 1159012521131872484    2
# 1156694461618365500    2
#                       ..
# 913295816419814236     1
# 1005919947752546103    1
# 54003850               1
# 24946435               1
# 941828367326510565     1
# Name: id, Length: 1438, dtype: int64

# %% [markdown]
# These are the same listings but the host changed listings geo coordinates:

# %%
df_unique[df_unique['id'] == 978918152395569293]
# Out:
#                      id     userId                                     name  \
# 182  978918152395569293  519475844  Guest Home 1st floor in North Vancouver
# 269  978918152395569293  519475844  Guest Home 1st floor in North Vancouver
#
#                          address             city  isSuperhost        lat  \
# 182  North Vancouver, BC, Canada  North Vancouver         True  49.312510
# 269  North Vancouver, BC, Canada  North Vancouver         True  49.312038
#
#             lng  persons  rating  reviewsCount         type  \
# 182 -123.009580        4    4.93            42  Entire home
# 269 -123.008392        4    4.93            42  Entire home
#
#                                cancelPolicy  \
# 182  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
# 269  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
#
#                                               deeplink  \
# 182  https://www.airbnb.com/rooms/97891815239556929...
# 269  https://www.airbnb.com/rooms/97891815239556929...
#
#                                          hostThumbnail price_currency  \
# 182  https://a0.muscache.com/im/pictures/user/User-...            CAD
# 269  https://a0.muscache.com/im/pictures/user/User-...            CAD
#
#      price_rate  price_total  bathrooms  bedrooms  beds  \
# 182         298          298        1.0         1     2
# 269         298          298        1.0         1     2
#
#                       previewAmenities  \
# 182  Free parking, Wifi, Self check-in
# 269  Free parking, Wifi, Self check-in
#
#                                                  url  \
# 182  https://www.airbnb.com/rooms/978918152395569293
# 269  https://www.airbnb.com/rooms/978918152395569293
#
#                                                 images  \
# 182  ['https://a0.muscache.com/im/pictures/b191a872...
# 269  ['https://a0.muscache.com/im/pictures/b191a872...
#
#                                             amenityIds
# 182  [64, 1, 4, 71, 72, 9, 73, 137, 74, 77, 79, 145...
# 269  [64, 1, 4, 71, 72, 9, 73, 137, 74, 77, 79, 145...

# %%
df_unique[df_unique['id'] == 1156694461618365500]
# Out:
#                       id     userId                                   name  \
# 286  1156694461618365500  509295500  Modern Guest Suite In North Vancouver
# 179  1156694461618365500  509295500  Modern Guest Suite In North Vancouver
#
#                          address             city  isSuperhost        lat  \
# 286  North Vancouver, BC, Canada  North Vancouver        False  49.313471
# 179  North Vancouver, BC, Canada  North Vancouver        False  49.314457
#
#             lng  persons  rating  reviewsCount         type  \
# 286 -123.006413        4     0.0             1  Entire home
# 179 -123.006674        4     0.0             0  Entire home
#
#                                cancelPolicy  \
# 286  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
# 179  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
#
#                                               deeplink  \
# 286  https://www.airbnb.com/rooms/11566944616183655...
# 179  https://www.airbnb.com/rooms/11566944616183655...
#
#                                          hostThumbnail price_currency  \
# 286  https://a0.muscache.com/im/pictures/user/5d008...            CAD
# 179  https://a0.muscache.com/im/pictures/user/5d008...            CAD
#
#      price_rate  price_total  bathrooms  bedrooms  beds  \
# 286         298          298        1.0         1     2
# 179         251          251        1.0         1     2
#
#                                previewAmenities  \
# 286  Free parking, Wifi, Kitchen, Self check-in
# 179  Free parking, Wifi, Kitchen, Self check-in
#
#                                                   url  \
# 286  https://www.airbnb.com/rooms/1156694461618365500
# 179  https://www.airbnb.com/rooms/1156694461618365500
#
#                                                 images  \
# 286  ['https://a0.muscache.com/im/pictures/hosting/...
# 179  ['https://a0.muscache.com/im/pictures/hosting/...
#
#                                             amenityIds
# 286  [64, 1, 66, 4, 71, 8, 72, 9, 73, 137, 74, 394,...
# 179  [64, 1, 66, 4, 71, 8, 72, 9, 73, 137, 74, 394,...

# %%
# drop them

df_unique = df_unique.drop_duplicates(subset=['id', 'type'], keep='last')
print(df_unique.shape)
# Out:
# (1441, 25)

# %%
import folium

# Create a map object centered around an average location
map = folium.Map(location=[df_unique['lat'].mean(), df_unique['lng'].mean()], zoom_start=10)

# Add points
for _, row in df_unique.iterrows():
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=f"{row['id']}",  # Popup text that appears when you click the marker
    ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa08b4ff80c96aa3c9f98ac54c84f3f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa08b4ff80c96aa3c9f98ac54c84f3f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa08b4ff80c96aa3c9f98ac54c84f3f0 = L.map(
#                 &quot;map_aa08b4ff80c96aa3c9f98ac54c84f3f0&quot;,
#                 {
#                     center: [49.24546539574301, -123.06819731535846],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d38b889e5925603961046021072f7c76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d38b889e5925603961046021072f7c76.addTo(map_aa08b4ff80c96aa3c9f98ac54c84f3f0);
#
#
#             var marker_a5a6eb8e932a9a80745db971f4c42507 = L.marker(
#                 [49.25369, -123.09964],
#                 {}
#             ).addTo(map_aa08b4ff80c96aa3c9f98ac54c84f3f0);
#
#
#         var popup_61f38aaf96c195ccad2c0341d9292db1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e1b6299cc691e8d2a4c1d2f1ad2b88d = $(`&lt;div id=&quot;html_3e1b6299cc691e8d2a4c1d2f1ad2b88d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;51320938&lt;/div&gt;`)[0];
#                 popup_61f38aaf96c195ccad2c0341d9292db1.setContent(html_3e1b6299cc691e8d2a4c1d2f1ad2b88d);
#
#
#
#         marker_a5a6eb8e932a9a80745db971f4c42507.bindPopup(popup_61f38aaf96c195ccad2c0341d9292db1)
#         ;
#
#
#
#
#             var marker_f26968fbf99bf3ac4ba1717bbc910609 = L.marker(
#                 [49.23965, -123.04831],
#                 {}
#             ).addTo(map_aa08b4ff80c96aa3c9f98ac54c84f3f0);
#
#
#         var popup_5cf04fc9dd9176632b8f45f1309f55bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_620cbe77f929b6b6769641d55952f682 = $(`&lt;div id=&quot;html_620cbe77f929b6b6769641d55952f682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;21356520&lt;/div&gt;`)[0];
#                 popup_5cf04fc9dd9176632b8f45f1309f55bc.setContent(html_620cbe77f929b6b6769641d55952f682);
#
#
#
#         marker_f26968fbf99bf3ac4ba1717bbc910609.bindPopup(popup_5cf04fc9dd9176632b8f45f1309f55bc)
#         ;
#
#
#
#
#             var marker_fccdca8c7f355d9c4642b8f3d40dd7c5 = L.marker(
#                 [49.25254169893759, -123.08329939842224],
#                 {}
#             ).addTo(map_aa08b4ff80c96aa3c9f98ac54c84f3f0);
#
#
#         var popup_34170fd5dcab4ac3816094183c2c51f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f9b200464b7315fe5f62cbd85836bf6 = $(`&lt;div id=&quot;html_3f9b200464b7315fe5f62cbd85836bf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1064160331460880461&lt;/div&gt;`)[0];
#                 popup_34170fd5dcab4ac3816094183c2c51f6.setContent(html_3f9b200464b7315fe5f62cbd85836bf6);
#
#
#
#         marker_fccdca8c7f355d9c4642b8f3d40dd7c5.bindPopup(popup_34170fd5dcab4ac3816094183c2c51f6)
#         ;
#
#
#
#
#             var marker_ba2e48fa3872ba27ea14497b8a94d358 = L.marker(
#                 [49.28459856667694, -123.12993193932368],
#                 {}
#             ).addTo(map_aa08b4ff80c96aa3c9f98ac54c84f3f0);
#
#
#         var popup_e9d759ddb80072d51011c9c23e439b19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6aba3502b3eeefbc85fe93cb12887df2 = $(`&lt;div id=&quot;html_6aba3502b3eeefbc85fe93cb12887df2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1061140108656427369&lt;/div&gt;`)[0];
#                 popup_e9d759ddb80072d51011c9c23e439b19.setContent(html_6aba3502b3eeefbc85fe93cb12887df2);
#
#
#
#         marker_ba2e48fa3872ba27ea14497b8a94d358.bindPopup(popup_e9d759ddb80072d51011c9c23e439b19)
#         ;
#
#
#
#
#             var marker_91e6590ec7db1186a240fea04f75b5fe = L.marker(
#                 [49.27776, -123.12797],
#                 {}
#             ).addTo(map_aa08b4ff80c96aa3c9f98ac54c84f3f0);
#
#
#         var popup_4afe1a0135c0ff2712f63efc872fed96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c76dc58e7ee8445be3dc05743b81e937 = $(`&lt;div id=&quot;html_c76dc58e7ee8445be3dc05743b81e937&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;660744993743958889&lt;/div&gt;`)[0];
#                 popup_4afe1a0135c0ff2712f63efc872fed96.setContent(html_c76dc58e7ee8445be3dc05743b81e937);
#
#
#
#         marker_91e6590ec7db1186a240fea04f75b5fe.bindPopup(popup_4afe1a0135c0ff2712f63efc872fed96)
#         ;
#
#
#
#
#             var marker_719cead7199c15135f0fdcb82d1581ab = L.marker(
#                 [49.2796404, -123.1088566],
#                 {}

# %%
df_unique.head()
# Out:
#                     id     userId  \
# 1             51320938   30084673
# 4             21356520   11824155
# 5  1064160331460880461   32377505
# 7  1061140108656427369  527093571
# 8   660744993743958889   79910358
#
#                                              name                address  \
# 1               NEW, clean, modern, private suite  Vancouver, BC, Canada
# 4       Private and spacious  room in upper floor  Vancouver, BC, Canada
# 5    Well-connected bright suite with home office  Vancouver, BC, Canada
# 7         Gorgeous 1Bd With Private Rooftop Patio  Vancouver, BC, Canada
# 8  Funky 1 bedroom in downtown Van (AC & Parking)  Vancouver, BC, Canada
#
#         city  isSuperhost        lat         lng  persons  rating  \
# 1  Vancouver         True  49.253690 -123.099640        2    4.92
# 4  Vancouver         True  49.239650 -123.048310        2    4.90
# 5  Vancouver         True  49.252542 -123.083299        2    4.81
# 7  Vancouver        False  49.284599 -123.129932        2    4.80
# 8  Vancouver         True  49.277760 -123.127970        3    4.86
#
#    reviewsCount                  type                            cancelPolicy  \
# 1           107           Entire home  CANCEL_BETTER_STRICT_WITH_GRACE_PERIOD
# 4           112  Private room in home                         CANCEL_MODERATE
# 5            16    Entire guest suite      CANCEL_STRICT_14_WITH_GRACE_PERIOD
# 7             5    Entire rental unit                         CANCEL_MODERATE
# 8           100          Entire condo      CANCEL_STRICT_14_WITH_GRACE_PERIOD
#
#                                             deeplink  \
# 1  https://www.airbnb.com/rooms/51320938?check_in...
# 4  https://www.airbnb.com/rooms/21356520?check_in...
# 5  https://www.airbnb.com/rooms/10641603314608804...
# 7  https://www.airbnb.com/rooms/10611401086564273...
# 8  https://www.airbnb.com/rooms/66074499374395888...
#
#                                        hostThumbnail price_currency  \
# 1  https://a0.muscache.com/im/pictures/user/27680...            CAD
# 4  https://a0.muscache.com/im/pictures/user/eeb58...            CAD
# 5  https://a0.muscache.com/im/pictures/user/9a930...            CAD
# 7  https://a0.muscache.com/im/pictures/user/User-...            CAD
# 8  https://a0.muscache.com/im/pictures/user/User-...            CAD
#
#    price_rate  price_total  bathrooms  bedrooms  beds  \
# 1         224          896        1.0         1     2
# 4         107          427        1.0         1     1
# 5         207          827        1.0         1     1
# 7         429         1714        1.0         0     0
# 8         435         1738        1.0         1     2
#
#                              previewAmenities  \
# 1                Wifi, Kitchen, Self check-in
# 4                          Free parking, Wifi
# 5           Free parking, Wifi, Self check-in
# 7                Wifi, Kitchen, Self check-in
# 8  Free parking, Wifi, Kitchen, Self check-in
#
#                                                 url  \
# 1             https://www.airbnb.com/rooms/51320938
# 4             https://www.airbnb.com/rooms/21356520
# 5  https://www.airbnb.com/rooms/1064160331460880461
# 7  https://www.airbnb.com/rooms/1061140108656427369
# 8   https://www.airbnb.com/rooms/660744993743958889
#
#                                               images  \
# 1  ['https://a0.muscache.com/im/pictures/400ac6fc...
# 4  ['https://a0.muscache.com/im/pictures/edcf7494...
# 5  ['https://a0.muscache.com/im/pictures/hosting/...
# 7  ['https://a0.muscache.com/im/pictures/hosting/...
# 8  ['https://a0.muscache.com/im/pictures/miso/Hos...
#
#                                           amenityIds
# 1  [1, 33, 34, 35, 4, 100, 8, 40, 41, 44, 45, 51,...
# 4  [1, 129, 2, 4, 9, 73, 522, 77, 79, 146, 85, 86...
# 5  [4, 392, 9, 73, 137, 522, 77, 79, 657, 146, 85...
# 7  [1, 33, 34, 35, 4, 36, 37, 39, 8, 40, 41, 45, ...
# 8  [1, 4, 5, 8, 9, 137, 10, 522, 12, 15, 145, 657...

# %%
df_unique.persons.value_counts()
# Out:
# 2     758
# 4     293
# 3     148
# 1     123
# 6      54
# 5      39
# 8      14
# 10      6
# 7       3
# 12      2
# 11      1
# Name: persons, dtype: int64

# %%
print(f'{df_unique.shape=}')
# Out:
# df_unique.shape=(1441, 25)

# %%
listings_by_host = df_unique[['id', 'userId']].groupby('userId').count().value_counts()
listings_by_host
# Out:
# id
# 1     1040
# 2      104
# 3       33
# 4       15
# 5        4
# 7        2
# dtype: int64

# %%
# type                                number of values
df_unique.type.value_counts()
# Out:
# Private room in home                  359
# Entire guest suite                    307
# Entire rental unit                    214
# Entire home                           208
# Entire condo                          140
# Entire guesthouse                      44
# Entire loft                            24
# Private room in villa                  23
# Private room in condo                  22
# Private room in rental unit            18
# Private room in guest suite            13
# Private room in bed and breakfast      12
# Private room in townhouse              10
# Private room in guesthouse              5
# Entire townhouse                        5
# Tiny home                               5
# Room in hotel                           4
# Room in boutique hotel                  3
# Entire cottage                          2
# Private room in farm stay               2
# Entire villa                            2
# Houseboat                               2
# Private room in boat                    2
# Entire serviced apartment               2
# Private room in houseboat               1
# Private room                            1
# Private room in resort                  1
# Entire place                            1
# Shared room in home                     1
# Private room in bungalow                1
# Entire vacation home                    1
# Shared room in condo                    1
# Boat                                    1
# Camper/RV                               1
# Private room in tiny home               1
# Private room in casa particular         1
# Private room in serviced apartment      1
# Name: type, dtype: int64

# %%
# data.to_csv("../data/df_unique.csv", index=False)
